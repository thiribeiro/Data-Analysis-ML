# %% [markdown]
# # Denzel Washington Movies IMDb - EDA

# %% [markdown]
# # Denzel Washington's movies analysis using data collected from IMDb.
#
# #### P.S.: I'm not responsible for the information avaiable. This is just an analysis using data from IMDb. Some time ago, Denzel said that information about his movies from IMDb should be corrected: https://heavy.com/entertainment/2013/08/2-guns-interview-denzel-mark-wahlberg/

# %%
#Libraries to Data Analysis
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## Some Questions can be answered in this analisys...
# #### 1) How many Productions(movies) Denzel worked? <br> 1.1)Total of Productions <br> 1.2) Productions by Year<br> 1.3) Productions by Decade<br>
# #### 2) Which Director Denzel more worked in his carreer? <br> 2.1) Which movies Denzel worked with this directors?<br> 2.2) Which movies Denzel Acted and Directed simultaneously?<br>
# #### 3) The genre of his movies changed with time?<br> 3.1) Genre by Quantity<br> 3.2) Genre by Decade<br>
# #### 4) Movies' duration<br> 4.1) Longest Movies<br> 4.2) Shortest Movies<br>
# #### 5) Better and Worst Movies (by Metacritic (METASCORE) and by IMDb)<br> 5.1) Individual Evaluation(by IMDb and METASCORE)<br> 5.2) Comparison between 2 evaluations<br> 5.3) IMDb's Evaluation by genre <br> 5.4) Metacritic's Evaluation by genre <br>
# #### 6) Wordclouds <br> 6.1) Movie synopse's wordcloud <br> 6.2) Movie title's Wordcloud

# %%
#Getting .csv file
df = pd.read_csv('../input/denzel-imdb-movies/filmes_denzel_V2.csv',sep=',', encoding='ISO-8859-1')

# %%
df.head(4)

# %%
#df.shape

# %%
#df.isnull().any()

# %%
import matplotlib.pyplot as plt
#%matplotlib inline

# %% [markdown]
# ## 1) How many Productions(movies) Denzel worked?

# %% [markdown]
#  In this dataset, i got only the productions Denzel was credited as actor and/or director in movies, series and animations.<br>
#  P.S.: Denzel's apparitions as himself in any production(including documentaries) were desconsidered.

# %% [markdown]
# ## 1.1) Total of Productions

# %%
df.shape[0]

# %% [markdown]
# The actor was credited in 56 productions so far, acting, directing or both, in movies and series, being or not the main actor.

# %% [markdown]
# ## 1.2) Productions by Year

# %%
#Excluindo anos sem informação
dfGraphAno = df['Ano'] 
dfGraphAno = dfGraphAno[dfGraphAno != 0]
dfGraphAno = dfGraphAno.sort_values(ascending=True)

plt.rcParams['figure.figsize'] = (11,7)
plt.figure();
plt.title('Productions by Year')
plt.ylabel('Qtt of Productions')
plt.yticks(range(0,len(dfGraphAno)))
plt.xlabel('Year')
    
dfGraphAno.value_counts().sort_index(ascending=True).plot(kind='bar');

# %% [markdown]
# As we can see, the quantity of participations vary between 1 and 3 movies by year.<br>
# Based on that, the years with max qtt of movies were: 1993, 1995 and 1998, with 3 movies each.

# %% [markdown]
# ## 1.3) Productions by Decade

# %%
#Decade function, based on year
def pegaDecada(ano):
    if ano >= 1970 and ano < 1980:
        decada = 1970
    elif ano >= 1980 and ano < 1990:
        decada = 1980
    elif ano >= 1990 and ano < 2000:
        decada = 1990
    elif ano >= 2000 and ano < 2010:
        decada = 2000
    elif ano >= 2010 and ano < 2020:
        decada = 2010
    elif ano >= 2020 and ano < 2030:
        decada = 2020
    else: 
        decada = 0
        
    return decada    

#x = pegaDecada(1985)
#x

# %%
#Creating Decade column on dataframe
qtdProd = df.shape[0]
listDecada = []

for i in range(qtdProd):
    x = pegaDecada(df['Ano'][i])
    listDecada.append(x)
    #print (x)

df['Decada'] = listDecada
#df

# %%
#Deleting years without data
dfGraphDec = df['Decada'] 
dfGraphDec = dfGraphDec[dfGraphDec != 0]
dfGraphDec = dfGraphDec.sort_values(ascending=True)

plt.rcParams['figure.figsize'] = (11,7)
plt.figure();
plt.title('Productions by Decade')
plt.ylabel('Qtt of Productions')
plt.yticks(range(0,len(dfGraphDec)))
plt.xlabel('Decade')
    
dfGraphDec.value_counts().sort_index().plot(kind='bar');

# %%
#dfGraphDec.value_counts()

# %% [markdown]
# According to data, the number of Denzel's participations in productions is consistent since 1980's.<br>
# We can see that the 1990's were the decade with most number of participations(19), followed by 2000's(12) and 2010's(10).<br>
# 1980's didn't hit top 3 only by 1 participation(9).<br>
# Considering that 2010's didn't end yet, is possible that the number of participations increase and tie or passes 2000's. Only time will show that.

# %% [markdown]
# ## 2) Which Director Denzel more worked in his carreer?

# %%
#Creating 'Others' category in Director column, based on qtt of movies(<=2)
dfDiretor = df 
dfDiretor.loc[dfDiretor['Diretor'].isin((dfDiretor['Diretor'].value_counts()[dfDiretor['Diretor'].value_counts() < 2]).index), 'Diretor'] = 'Outros'
#dfDiretor
#df

# %%
#Deleting Directors with less than 2 movies
dfGraphDir = dfDiretor[dfDiretor['Diretor'] != 'Outros']
dfGraphDir = dfGraphDir[dfGraphDir['Diretor'].notnull()]

# %%
#Director's graph
plt.rcParams['figure.figsize'] = (11,7)
plt.figure();
plt.title('Directors that made movies with Denzel')
plt.xlabel('Qtt of Movies')
plt.ylabel('Directors')
dfGraphDir['Diretor'].value_counts(ascending=True).plot(kind='barh');

# %% [markdown]
# Director Tony Scott (deceased)leads the list with 5 movies, followed by Antoine Fuqua and Spike Lee(4 movies each). Denzel directed 3 movies with him acting too. Carl Franklin, Johnathan Demme, Jud Taylor and Norman Jewison directed Denzel 2 times each.

# %% [markdown]
# ## 2.1) Which movies Denzel worked with this directors?

# %%
#Movies/diretor list
dfGraphDir[['Diretor','Titulo','Ano']].sort_values(['Diretor','Ano'], ascending=[False, False])

# %% [markdown]
# ## 2.2) Which movies Denzel Acted and Directed simultaneously?

# %%
#Movies that Denzel acted and directed simultaneously
dfDirDenz = dfGraphDir[dfGraphDir['Diretor'] == 'Denzel Washington']
dfDirDenz[['Diretor','Titulo','Ano']].sort_values(['Diretor','Ano'], ascending=[False, False])

# %% [markdown]
# This question was answered in previous topic.<br>
# As showed before, Denzel acted and directed simultaneously in 3 productions so far.

# %% [markdown]
# ## 3) The genre of his movies changed with time?

# %%
dfGraphGen = df
dfGraphGen = dfGraphGen[dfGraphGen['Ano'] != 0]
#dfGraphGen

# %% [markdown]
# ## 3.1) Genre by Quantity

# %%
#Most common movie genres
#Graph considering the first genre of the movie...
plt.rcParams['figure.figsize'] = (11,7)
plt.figure();
plt.title('Genre of Productions')
plt.xlabel('Genre')
plt.ylabel('Quantity')
plt.yticks(range(0,len(dfGraphGen)))
dfGraphGen['Genero'].value_counts(ascending=False).plot(kind='bar');

# %% [markdown]
# ## 3.2) Genre by Decade

# %%
#dfGraphGen

# %%
#Creating crosstable with genre and decade in order to create the graph
tabGenDec = pd.crosstab(index=dfGraphGen['Decada'], columns=dfGraphGen['Genero'])
#tabGenDec

# %%
#Creating graph...
tabGenDec.plot(kind="line",figsize=(11,7),stacked=False)

# %% [markdown]
# <b>Action:</b> As we saw in previous graph, Denzel made more action movies than any other genre. The growth of participations in that genre started in 1980's - 1990's, having a decrease in 2000's, and increasing in actual decade.<br> <b>Comedy:</b> Denzel's participations in comedy productions has its prime in 1990's and since 2000's his participations in this genre are pratically nonexistent.<br> <b>Biography:</b> Biography genre has its prime in 2000's and after that only decrease in following decades. <br> <b>Crime:</b> Participations in this genre has its prime in 1990's and 2000's. After that, only decreased.<br> <b>Drama:</b> Drama genre has its prime on 1990's and decreased on 2000's. Started increase again on 2010's.

# %% [markdown]
# ## 4) Movies' duration

# %% [markdown]
# ### Which were the longest and the shortest movies Denzel participated?

# %% [markdown]
# ## 4.1) Longest Movies

# %%
#TOP 3 longest movies
dfDurFilm = dfGraphDir[dfGraphDir['Duracao'] != 0]
dfDurFilm[['Titulo','Duracao']].sort_values(by='Duracao', ascending=False).head(3)

# %% [markdown]
# ## 4.2) Shortest Movies

# %%
#TOP 3 shortest movies
dfDurFilm[['Titulo','Duracao']].sort_values(by='Duracao', ascending=True).head(3)

# %% [markdown]
# ## 5) Better and Worst Movies (by Metacritic (METASCORE) and by IMDb)

# %% [markdown]
# ## 5.1) Individual Evaluation (by Metacritic (METASCORE) and by IMDb)

# %%
#TOP 10 better grades from IMDB
#df.sort_values(by='Nota IMDB', ascending=False)
dfGraphDir[['Titulo','Nota IMDB']].sort_values(by='Nota IMDB', ascending=False).head(10)

# %%
#TOP 10 worst grades from IMDb
dfGraphDir[['Titulo','Nota IMDB']].sort_values(by='Nota IMDB', ascending=True).head(10)

# %%
#TOP 10 better grades from MetaScore
dfGraphDir[['Titulo','Nota Metascore']].sort_values(by='Nota Metascore', ascending=False).head(10)

# %%
dfNotas1 = dfGraphDir[dfGraphDir['Nota Metascore'] != 0]
dfNotas1[['Titulo','Nota Metascore']].sort_values(by='Nota Metascore', ascending=True).head(10)

# %% [markdown]
# ## 5.2) Comparison between 2 evaluations

# %%
##dfGraphGen
##Putting grades in same scale...
dfGraphGen['Nota Metascore'] = dfGraphGen['Nota Metascore']/10

# %%
#Keeping only Movies with grades in IMDb and Metacritic simutaneously
dfNotas = dfGraphGen[['Titulo','Nota IMDB','Nota Metascore']]
dfNotas2 = dfNotas[dfNotas['Nota Metascore'] != 0]
#dfNotas2

# %%
#dfNotas2.plot(x=dfNotas2['Titulo'],  kind='bar', 
#              figsize=(11,15),title='IMDB x METASCORE', yticks=(range(0,10)), stacked=False);
dfNotas2.plot(x='Titulo', kind='bar', 
              figsize=(11,15), title='IMDB x METASCORE', yticks=(range(0,10)), stacked=False);

# %% [markdown]
# ## 5.3) IMDb's Evaluation by genre

# %%
from matplotlib import cm
cmap = cm.get_cmap('Spectral')

# %%
#Gerando tabela cruzada(somente com gênero e nota IMDb) para criar o grafico
tabGenIMDb = pd.crosstab(index=dfGraphGen['Nota IMDB'], columns=dfGraphGen['Genero'])
#tabGenIMDb
#Creating graph...
tabGenIMDb.plot(kind="barh",figsize=(11,7), legend='reverse',  stacked=True)

# %% [markdown]
# ## 5.4) Metacritic's Evaluation by genre

# %%
#Creating crosstable with genre and metascore in order to create graph
dfx = dfGraphGen[dfGraphGen['Nota Metascore'] != 0]
tabGenIMDb = pd.crosstab(index=dfx['Nota Metascore'], columns=dfx['Genero'])
#tabGenIMDb
#Creating graph...
tabGenIMDb.plot(kind="barh",figsize=(11,7), stacked=True)

# %% [markdown]
# ## 6) Wordclouds ¶

# %% [markdown]
# Creating wordclouds with words from synopsis and title of productions

# %% [markdown]
# ## 6.1) Movie synopse's wordcloud

# %%
#Wordcloud and stopword libraries
from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator
from os import path

# %%
#Read synopsis and creating unique string
sinopses = str(df['Sinopse'])
#sinopses

# %%
#Defining stopwords list
stopwords= set(STOPWORDS)

#Adding portuguese stopwords
new_words = []
with open("../input/stopwords-portuguese/stopwords_portuguese.txt", encoding='latin-1', mode='r') as f:
    [new_words.append(word) for line in f for word in line.split()]

new_stopwords = stopwords.union(new_words)

# %%
def printWordCloud(x):
    plt.figure(figsize=(20,10))
    wc = WordCloud(min_font_size=10, 
               max_font_size=300, 
               background_color='black', 
               mode="RGB",
               width=2000, 
               height=1000,
               stopwords=new_stopwords,
               normalize_plurals= True).generate(x)
    plt.imshow(wc, interpolation="bilinear")
    plt.axis("off")
    plt.show()

# %%
#Printing wordcloud
printWordCloud(sinopses)

# %% [markdown]
# ## 6.2) Movie title's wordcloud

# %%
titulo = str(df['Titulo'])
#titulo

# %%
printWordCloud(titulo)
